# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datascience import *
import plotly.express as px

# %%
Vehicle_Type_2018 = pd.read_csv('/work/vehicle-fuel-type-count-by-zip-code (1).csv')
Vehicle_Type_2020 = pd.read_csv('vehicle-count-as-of-1-1-2020.csv')
asthma = pd.read_csv('asthma-hospitalization-rates-by-county-2015_2019.csv')
cal_2018 = pd.read_csv('calenviroscreen-3.0-results-june-2018-update.csv')
cal_2018 = pd.read_csv('calenviroscreen-3.0-results-june-2018-update.csv')
# Out:
# /shared-libs/python3.9/py-core/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3139: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /shared-libs/python3.9/py-core/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3139: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#plotting poverty vs fuel type
#evs = Vehicle_Type_2018[Vehicle_Type_2018["Duty"]=="Light"].groupby("Zip Code",as_index=False).sum()
#cal_asthma = cal_2018[["ZIP","Asthma"]].groupby("ZIP",as_index=False).mean()
cal_map = cal_2018[cal_2018["Total Population"]>=1000]
cal_map = cal_map[cal_map["ZIP"]>=90000]
cal_map = cal_map[["Longitude","Latitude","Haz. Waste"]]
cal_map = cal_map.groupby(["Longitude","Latitude"]).agg({"Haz. Waste": "sum"}).reset_index()
cal_map = cal_map[cal_map["Haz. Waste"]!=0]
#cal_map = cal_map.pivot_table(values="Haz. Waste",index=["Longitude"],columns=["Latitude"],aggfunc=sum)
#cal_map
fig = px.scatter_mapbox(cal_map,lat="Latitude",lon="Longitude", color="Haz. Waste",color_continuous_scale=px.colors.cyclical.IceFire)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
#cal_asthma = cal_asthma[cal_asthma["ZIP"]>=90000]
#cal_poverty = cal_2018[["ZIP","Poverty"]].groupby("ZIP",as_index=False).mean()
#combo = evs.merge(cal_asthma, left_on="Zip Code",right_on="ZIP")
#combo
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=47c57360-7945-4d7b-ba23-4ebc77d34422' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
